# %% [markdown]
# <a href="https://colab.research.google.com/github/MinaAlberDS/Codveda-Internship/blob/master/Web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scrapping, and collecting the data
#
# ### Collecting the houses links

# %%
# Import the needed libraries
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd
# Make the function which will get the houses links
def houses_links(pages, verbose):
    """
    Scrapes real estate listing links from realestate.gov.eg.

    Args:
        pages: An integer representing the number of pages to scrape.
        verbose: A boolean indicating whether to print the progress of scraping each page.

    Returns:
        A list of strings, where each string is a URL to a real estate listing.
    """
    base_url = r"https://realestate.gov.eg/properties?page={}" # Base url template

    links = [] # links list
    for page in range(1,pages+1): # This for loop to get the 9 houses links in each page
        start_time = time.perf_counter() # start a stop watch for each page
        page_url = base_url.format(page) # Set the page url from the baseline url using f-string or format
        response = requests.get(page_url) # Get the response of the page url
        if response.status_code == 200: # check if the page can be scrapped or not
          soop = BeautifulSoup(response.content, "html.parser") # set the soop variable to scrape the links from the page html
          houses = soop.find_all("div", class_="col-md-4")[3:] # get the houses links

          for house in houses: # Add the houses links to the links list
              link = r"https://realestate.gov.eg" + house.find("a")["href"] # Set the house url
              links.append(link) # add it to the links list
          end_time = time.perf_counter() # stop the timer
          elapsed = end_time - start_time # count the elapsed time
          if verbose: # if the verbose is true, it will show some useful information about each page
              print(f"Page: {page} links have been appended in {elapsed:.4f}s")
        else: # if the page cannot be scraped
          print(f"failed to scrape this Page: {page} with code: {response.status_code}")
    return links # finally retrun the links list

# %%
links = houses_links(100, True) # running our function with 56 pages, and verbose = True
# Out:
# Page: 1 links have been appended in 1.6158s
# Page: 2 links have been appended in 1.1227s
# Page: 3 links have been appended in 1.1321s
# Page: 4 links have been appended in 1.8412s
# Page: 5 links have been appended in 1.1842s
# Page: 6 links have been appended in 1.0489s
# Page: 7 links have been appended in 1.2277s
# Page: 8 links have been appended in 1.1783s
# Page: 9 links have been appended in 1.2382s
# Page: 10 links have been appended in 1.1127s
# Page: 11 links have been appended in 1.1664s
# Page: 12 links have been appended in 1.3009s
# Page: 13 links have been appended in 1.0830s
# Page: 14 links have been appended in 1.2597s
# Page: 15 links have been appended in 1.1812s
# Page: 16 links have been appended in 1.1803s
# Page: 17 links have been appended in 1.3764s
# Page: 18 links have been appended in 1.2706s
# Page: 19 links have been appended in 1.1003s
# Page: 20 links have been appended in 1.0703s
# Page: 21 links have been appended in 1.1615s
# Page: 22 links have been appended in 1.0774s
# Page: 23 links have been appended in 1.0797s
# Page: 24 links have been appended in 1.1568s
# Page: 25 links have been appended in 1.1485s
# Page: 26 links have been appended in 1.1514s
# Page: 27 links have been appended in 1.2988s
# Page: 28 links have been appended in 1.0126s
# Page: 29 links have been appended in 1.5849s
# Page: 30 links have been appended in 1.1275s
# Page: 31 links have been appended in 1.1840s
# Page: 32 links have been appended in 1.5050s
# Page: 33 links have been appended in 1.2378s
# Page: 34 links have been appended in 1.2543s
# Page: 35 links have been appended in 1.2212s
# Page: 36 links have been appended in 1.1310s
# Page: 37 links have been appended in 1.1955s
# Page: 38 links have been appended in 1.0629s
# Page: 39 links have been appended in 1.4088s
# Page: 40 links have been appended in 1.3624s
# Page: 41 links have been appended in 1.2166s
# Page: 42 links have been appended in 1.2553s
# Page: 43 links have been appended in 1.1570s
# Page: 44 links have been appended in 1.2476s
# Page: 45 links have been appended in 1.0520s
# Page: 46 links have been appended in 1.0571s
# Page: 47 links have been appended in 1.1022s
# Page: 48 links have been appended in 1.1527s
# Page: 49 links have been appended in 1.3368s
# Page: 50 links have been appended in 1.1560s
# Page: 51 links have been appended in 1.1518s
# Page: 52 links have been appended in 1.1827s
# Page: 53 links have been appended in 1.2237s
# Page: 54 links have been appended in 1.6636s
# Page: 55 links have been appended in 1.1130s
# Page: 56 links have been appended in 1.2162s
# Page: 57 links have been appended in 1.4046s
# Page: 58 links have been appended in 1.2190s
# Page: 59 links have been appended in 1.1022s
# Page: 60 links have been appended in 1.1154s
# Page: 61 links have been appended in 1.4679s
# Page: 62 links have been appended in 1.3329s
# Page: 63 links have been appended in 1.6567s
# Page: 64 links have been appended in 1.4355s
# Page: 65 links have been appended in 1.0361s
# Page: 66 links have been appended in 1.1239s
# Page: 67 links have been appended in 1.0896s
# Page: 68 links have been appended in 1.3319s
# Page: 69 links have been appended in 1.1108s
# Page: 70 links have been appended in 1.2531s
# Page: 71 links have been appended in 1.1055s
# Page: 72 links have been appended in 1.0884s
# Page: 73 links have been appended in 1.5233s
# Page: 74 links have been appended in 1.1981s
# Page: 75 links have been appended in 1.3211s
# Page: 76 links have been appended in 1.2717s
# Page: 77 links have been appended in 1.0527s
# Page: 78 links have been appended in 1.2668s
# Page: 79 links have been appended in 1.1921s
# Page: 80 links have been appended in 1.3068s
# Page: 81 links have been appended in 1.1985s
# Page: 82 links have been appended in 1.3987s
# Page: 83 links have been appended in 1.1895s
# Page: 84 links have been appended in 1.0285s
# Page: 85 links have been appended in 1.1800s
# Page: 86 links have been appended in 1.1368s
# Page: 87 links have been appended in 1.1324s
# Page: 88 links have been appended in 1.1837s
# Page: 89 links have been appended in 1.1804s
# Page: 90 links have been appended in 1.0974s
# Page: 91 links have been appended in 1.1666s
# Page: 92 links have been appended in 1.1583s
# Page: 93 links have been appended in 1.1722s
# Page: 94 links have been appended in 1.3671s
# Page: 95 links have been appended in 1.1950s
# Page: 96 links have been appended in 1.1201s
# Page: 97 links have been appended in 1.0866s
# Page: 98 links have been appended in 1.0917s
# Page: 99 links have been appended in 1.1868s
# Page: 100 links have been appended in 1.1870s

# %%
len(links)
# Out:
# 900

# %% [markdown]
# We have 504 house to scrape

# %%
import json
# export the houses links to a json file
with open("Links.json", "w") as links_json:
    json.dump(links, links_json, indent =4)

# %%
# import the json file links to scrap them
with open("Links.json", "r") as links_json:
  links = json.load(links_json)
# show the results
links[:5]
# Out:
# ['https://realestate.gov.eg/property-details/alamain-(latin-district)/north-coast/alexandria/building-f04-floor-6-unit-z02-cl05-f04-x7-06-11-alamain-(latin-district)-north-coast-alexandria-egypt/E358149',
#  'https://realestate.gov.eg/property-details/beachfront-tower---b1/mersa-matruh/matrouh/building-btb1-floor-9th-floor-unit-btb1091-beachfront-tower---b1-mersa-matruh-(k)-matrouh-egypt/E111134',
#  'https://realestate.gov.eg/property-details/podia/cairo/cairo/floor-13th-unit-mpo-1304-a-bin-zayednorth-podia-cairo-cairo-egypt/E109916',
#  'https://realestate.gov.eg/property-details/mazarine-apartment/mersa-matruh/matrouh/building-mzcs15-floor-3rd-floor-unit-mzcs1531-mazarine-apartment-mersa-matruh-(k)-matrouh-egypt/E111209',
#  'https://realestate.gov.eg/property-details/alamain-(latin-district)/north-coast/alexandria/building-e01-floor-1-unit-z02-cl09-e01-x4-01-03-alamain-(latin-district)-north-coast-alexandria-egypt/E104257']

# %% [markdown]
# ### Collect the houses data

# %%
import json

def collect_house_data(houses_links, verbose):
    # Initialize a dictionary to store data for all houses
    all_houses_data = {
        'name': [],
        'price': [],
        'property_type': [],
        'bedrooms': [],
        'bathrooms': [],
        'sqm': [],
        'year_built': [],
        'features': [],
        'city': [],
        'governorate': [],
        'address': [],
        'description': []
    }

    # Open the JSON file in append mode outside the loop
    with open("Houses_data.json", "w") as houses_data:
        # Initialize the JSON file with an empty list
        json.dump([], houses_data)


    for i, house_link in enumerate(houses_links): # get the data from each house
        try:
            house_response = requests.get(house_link) # Get the request of the house link
            house_soop = BeautifulSoup(house_response.content, "html.parser") # make the house soop

            # Extract data, handling potential missing elements
            name = house_soop.find("h6", class_= "propertyInfo_name__bs0i7")
            all_houses_data['name'].append(name.get_text(strip=True) if name else None)

            price = house_soop.find("p", class_ = "propertyInfo_price__8ecPp")
            all_houses_data['price'].append(price.text.strip() if price else None)

            house_div = house_soop.find_all("div", class_= "propertySpecs_spec_box__xLU5D")
            if len(house_div) > 0:
                property_type = house_div[0].find("span")
                all_houses_data['property_type'].append(property_type.text.strip() if property_type else None)

                # Extract bedroom, bathroom, sqm, and year built if available

                bedroom = house_div[1].find_all("span")[1]
                all_houses_data['bedrooms'].append(bedroom.text.strip() if bedroom else None)
                bathroom = house_div[2].find_all("span")[1]
                all_houses_data['bathrooms'].append(bathroom.text.strip() if bathroom else None)
                sqm = house_div[3].find_all("span")[1]
                all_houses_data['sqm'].append(sqm.text.strip() if sqm else None)
                year_built = house_div[4].find_all("span")[1]
                all_houses_data['year_built'].append(year_built.text.strip() if year_built else None)

            else:
                # Append None for property type and other specs if the main div is not found
                all_houses_data['property_type'].append(None)
                all_houses_data['bedrooms'].append(None)
                all_houses_data['bathrooms'].append(None)
                all_houses_data['sqm'].append(None)
                all_houses_data['year_built'].append(None)


            house_features = []
            house_features_dv = house_soop.find_all("div", class_ = "col-md-6")
            for house_feature in house_features_dv:
                feature_text = house_feature.find("h2")
                if feature_text:
                    house_features.append(feature_text.get_text(strip=True))
            all_houses_data['features'].append(house_features) # Append the list of features


            house_city_div = house_soop.find_all("div", class_= "propertyData_address_info_row__up8MX")
            if len(house_city_div) > 2:
                city = house_city_div[1].find_all("p")
                all_houses_data['city'].append(city[1].get_text(strip=True) if len(city) > 1 else None)

                governorate = house_city_div[2].find_all("p")
                all_houses_data['governorate'].append(governorate[1].get_text(strip=True) if len(governorate) > 1 else None)
            else:
                # Append None if city and governorate details are not found
                all_houses_data['city'].append(None)
                all_houses_data['governorate'].append(None)


            address_div = house_soop.find("div", class_="propertyData_address_info_row__up8MX propertyData_address_row__vZiYP")
            if address_div:
                address = address_div.find_all("p")
                all_houses_data['address'].append(address[1].get_text(strip=True) if len(address) > 1 else None)
            else:
                # Append None if address is not found
                all_houses_data['address'].append(None)

            description_div = house_soop.find("div", class_= "propertyData_property_long_description__mAJPf")
            if description_div:
                 # Extract text from each paragraph tag and join them
                 paragraph_texts = [p.get_text(strip=True) for p in description_div.find_all("p")]
                 full_description = "".join(paragraph_texts)
                 all_houses_data['description'].append(full_description)
            else:
                # Append None if description is not found
                all_houses_data['description'].append(None)


            # Append the data of the current house to the JSON file
            with open("Houses_data.json", "r+") as houses_data:
                data = json.load(houses_data)
                data.append({key: all_houses_data[key][-1] for key in all_houses_data})  # Append the last added data
                houses_data.seek(0) # the begining of the file
                json.dump(data, houses_data, indent=4) # Add the house data
                houses_data.truncate() # The beining of the file

            if verbose:
                print(f"Scraped data for house {i+1}/{len(houses_links)}")

        except Exception as e:
            print(f"Error scraping {house_link}: {e}")
            # Append None for all fields if an error occurs during scraping
            for key in all_houses_data:
                all_houses_data[key].append(None)


    return all_houses_data

# %%
Houses_data = collect_house_data(links, True)
# Out:
# Scraped data for house 1/900
# Scraped data for house 2/900
# Scraped data for house 3/900
# Scraped data for house 4/900
# Scraped data for house 5/900
# Scraped data for house 6/900
# Scraped data for house 7/900
# Scraped data for house 8/900
# Scraped data for house 9/900
# Scraped data for house 10/900
# Scraped data for house 11/900
# Scraped data for house 12/900
# Scraped data for house 13/900
# Scraped data for house 14/900
# Scraped data for house 15/900
# Scraped data for house 16/900
# Scraped data for house 17/900
# Scraped data for house 18/900
# Scraped data for house 19/900
# Scraped data for house 20/900
# Scraped data for house 21/900
# Scraped data for house 22/900
# Scraped data for house 23/900
# Scraped data for house 24/900
# Scraped data for house 25/900
# Scraped data for house 26/900
# Scraped data for house 27/900
# Scraped data for house 28/900
# Scraped data for house 29/900
# Scraped data for house 30/900
# Scraped data for house 31/900
# Scraped data for house 32/900
# Scraped data for house 33/900
# Scraped data for house 34/900
# Scraped data for house 35/900
# Scraped data for house 36/900
# Scraped data for house 37/900
# Scraped data for house 38/900
# Scraped data for house 39/900
# Scraped data for house 40/900
# Scraped data for house 41/900
# Scraped data for house 42/900
# Scraped data for house 43/900
# Scraped data for house 44/900
# Scraped data for house 45/900
# Scraped data for house 46/900
# Scraped data for house 47/900
# Scraped data for house 48/900
# Scraped data for house 49/900
# Scraped data for house 50/900
# Scraped data for house 51/900
# Scraped data for house 52/900
# Scraped data for house 53/900
# Scraped data for house 54/900
# Scraped data for house 55/900
# Scraped data for house 56/900
# Scraped data for house 57/900
# Scraped data for house 58/900
# Scraped data for house 59/900
# Scraped data for house 60/900
# Scraped data for house 61/900
# Scraped data for house 62/900
# Scraped data for house 63/900
# Scraped data for house 64/900
# Scraped data for house 65/900
# Scraped data for house 66/900
# Scraped data for house 67/900
# Scraped data for house 68/900
# Scraped data for house 69/900
# Scraped data for house 70/900
# Scraped data for house 71/900
# Scraped data for house 72/900
# Scraped data for house 73/900
# Scraped data for house 74/900
# Scraped data for house 75/900
# Scraped data for house 76/900
# Scraped data for house 77/900
# Scraped data for house 78/900
# Scraped data for house 79/900
# Scraped data for house 80/900
# Scraped data for house 81/900
# Scraped data for house 82/900
# Scraped data for house 83/900
# Scraped data for house 84/900
# Scraped data for house 85/900
# Scraped data for house 86/900
# Scraped data for house 87/900
# Scraped data for house 88/900
# Scraped data for house 89/900
# Scraped data for house 90/900
# Scraped data for house 91/900
# Scraped data for house 92/900
# Scraped data for house 93/900
# Scraped data for house 94/900
# Scraped data for house 95/900
# Scraped data for house 96/900
# Scraped data for house 97/900
# Scraped data for house 98/900
# Scraped data for house 99/900
# Scraped data for house 100/900
# Scraped data for house 101/900
# Scraped data for house 102/900
# Scraped data for house 103/900
# Scraped data for house 104/900
# Scraped data for house 105/900
# Scraped data for house 106/900
# Scraped data for house 107/900
# Scraped data for house 108/900
# Scraped data for house 109/900
# Scraped data for house 110/900
# Scraped data for house 111/900
# Scraped data for house 112/900
# Scraped data for house 113/900
# Scraped data for house 114/900
# Scraped data for house 115/900
# Scraped data for house 116/900
# Scraped data for house 117/900
# Scraped data for house 118/900
# Scraped data for house 119/900
# Scraped data for house 120/900
# Scraped data for house 121/900
# Scraped data for house 122/900
# Scraped data for house 123/900
# Scraped data for house 124/900
# Scraped data for house 125/900
# Scraped data for house 126/900
# Scraped data for house 127/900
# Scraped data for house 128/900
# Scraped data for house 129/900
# Scraped data for house 130/900
# Scraped data for house 131/900
# Scraped data for house 132/900
# Scraped data for house 133/900
# Scraped data for house 134/900
# Scraped data for house 135/900
# Scraped data for house 136/900
# Scraped data for house 137/900
# Scraped data for house 138/900
# Scraped data for house 139/900
# Scraped data for house 140/900
# Scraped data for house 141/900
# Scraped data for house 142/900
# Scraped data for house 143/900
# Scraped data for house 144/900
# Scraped data for house 145/900
# Scraped data for house 146/900
# Scraped data for house 147/900
# Scraped data for house 148/900
# Scraped data for house 149/900
# Scraped data for house 150/900
# Scraped data for house 151/900
# Scraped data for house 152/900
# Scraped data for house 153/900
# Scraped data for house 154/900
# Scraped data for house 155/900
# Scraped data for house 156/900
# Scraped data for house 157/900
# Scraped data for house 158/900
# Scraped data for house 159/900
# Scraped data for house 160/900
# Scraped data for house 161/900
# Scraped data for house 162/900
# Scraped data for house 163/900
# Scraped data for house 164/900
# Scraped data for house 165/900
# Scraped data for house 166/900
# Scraped data for house 167/900
# Scraped data for house 168/900
# Scraped data for house 169/900
# Scraped data for house 170/900
# Scraped data for house 171/900
# Scraped data for house 172/900
# Scraped data for house 173/900
# Scraped data for house 174/900
# Scraped data for house 175/900
# Scraped data for house 176/900
# Scraped data for house 177/900
# Scraped data for house 178/900
# Scraped data for house 179/900
# Scraped data for house 180/900
# Scraped data for house 181/900
# Scraped data for house 182/900
# Scraped data for house 183/900
# Scraped data for house 184/900
# Scraped data for house 185/900
# Scraped data for house 186/900
# Scraped data for house 187/900
# Scraped data for house 188/900
# Scraped data for house 189/900
# Scraped data for house 190/900
# Scraped data for house 191/900
# Scraped data for house 192/900
# Scraped data for house 193/900
# Scraped data for house 194/900
# Scraped data for house 195/900
# Scraped data for house 196/900
# Scraped data for house 197/900
# Scraped data for house 198/900
# Scraped data for house 199/900
# Scraped data for house 200/900
# Scraped data for house 201/900
# Scraped data for house 202/900
# Scraped data for house 203/900
# Scraped data for house 204/900
# Scraped data for house 205/900
# Scraped data for house 206/900
# Scraped data for house 207/900
# Scraped data for house 208/900
# Scraped data for house 209/900
# Scraped data for house 210/900
# Scraped data for house 211/900
# Scraped data for house 212/900
# Scraped data for house 213/900
# Scraped data for house 214/900
# Scraped data for house 215/900
# Scraped data for house 216/900
# Scraped data for house 217/900
# Scraped data for house 218/900
# Scraped data for house 219/900
# Scraped data for house 220/900
# Scraped data for house 221/900
# Scraped data for house 222/900
# Scraped data for house 223/900
# Scraped data for house 224/900
# Scraped data for house 225/900
# Scraped data for house 226/900
# Scraped data for house 227/900
# Scraped data for house 228/900
# Scraped data for house 229/900
# Scraped data for house 230/900
# Scraped data for house 231/900
# Scraped data for house 232/900
# Scraped data for house 233/900
# Scraped data for house 234/900
# Scraped data for house 235/900
# Scraped data for house 236/900
# Scraped data for house 237/900
# Scraped data for house 238/900
# Scraped data for house 239/900
# Scraped data for house 240/900
# Scraped data for house 241/900
# Scraped data for house 242/900
# Scraped data for house 243/900
# Scraped data for house 244/900
# Scraped data for house 245/900
# Scraped data for house 246/900
# Scraped data for house 247/900
# Scraped data for house 248/900
# Scraped data for house 249/900
# Scraped data for house 250/900
# Scraped data for house 251/900
# Scraped data for house 252/900
# Scraped data for house 253/900
# Scraped data for house 254/900
# Scraped data for house 255/900
# Scraped data for house 256/900
# Scraped data for house 257/900
# Scraped data for house 258/900
# Scraped data for house 259/900
# Scraped data for house 260/900
# Scraped data for house 261/900
# Scraped data for house 262/900
# Scraped data for house 263/900
# Scraped data for house 264/900
# Scraped data for house 265/900
# Scraped data for house 266/900
# Scraped data for house 267/900
# Scraped data for house 268/900
# Scraped data for house 269/900
# Scraped data for house 270/900
# Scraped data for house 271/900
# Scraped data for house 272/900
# Scraped data for house 273/900
# Scraped data for house 274/900
# Scraped data for house 275/900
# Scraped data for house 276/900
# Scraped data for house 277/900
# Scraped data for house 278/900
# Scraped data for house 279/900
# Scraped data for house 280/900
# Scraped data for house 281/900
# Scraped data for house 282/900
# Scraped data for house 283/900
# Scraped data for house 284/900
# Scraped data for house 285/900
# Scraped data for house 286/900
# Scraped data for house 287/900
# Scraped data for house 288/900
# Scraped data for house 289/900
# Scraped data for house 290/900
# Scraped data for house 291/900
# Scraped data for house 292/900
# Scraped data for house 293/900
# Scraped data for house 294/900
# Scraped data for house 295/900
# Scraped data for house 296/900
# Scraped data for house 297/900
# Scraped data for house 298/900
# Scraped data for house 299/900
# Scraped data for house 300/900
# Scraped data for house 301/900
# Scraped data for house 302/900
# Scraped data for house 303/900
# Scraped data for house 304/900
# Scraped data for house 305/900
# Scraped data for house 306/900
# Scraped data for house 307/900
# Scraped data for house 308/900
# Scraped data for house 309/900
# Scraped data for house 310/900
# Scraped data for house 311/900
# Scraped data for house 312/900
# Scraped data for house 313/900
# Scraped data for house 314/900
# Scraped data for house 315/900
# Scraped data for house 316/900
# Scraped data for house 317/900
# Scraped data for house 318/900
# Scraped data for house 319/900
# Scraped data for house 320/900
# Scraped data for house 321/900
# Scraped data for house 322/900
# Scraped data for house 323/900
# Scraped data for house 324/900
# Scraped data for house 325/900
# Scraped data for house 326/900
# Scraped data for house 327/900
# Scraped data for house 328/900
# Scraped data for house 329/900
# Scraped data for house 330/900
# Scraped data for house 331/900
# Scraped data for house 332/900
# Scraped data for house 333/900
# Scraped data for house 334/900
# Scraped data for house 335/900
# Scraped data for house 336/900
# Scraped data for house 337/900
# Scraped data for house 338/900
# Scraped data for house 339/900
# Scraped data for house 340/900
# Scraped data for house 341/900
# Scraped data for house 342/900
# Scraped data for house 343/900
# Scraped data for house 344/900
# Scraped data for house 345/900
# Scraped data for house 346/900
# Scraped data for house 347/900
# Scraped data for house 348/900
# Scraped data for house 349/900
# Scraped data for house 350/900
# Scraped data for house 351/900
# Scraped data for house 352/900
# Scraped data for house 353/900
# Scraped data for house 354/900
# Scraped data for house 355/900
# Scraped data for house 356/900
# Scraped data for house 357/900
# Scraped data for house 358/900
# Scraped data for house 359/900
# Scraped data for house 360/900
# Scraped data for house 361/900
# Scraped data for house 362/900
# Scraped data for house 363/900
# Scraped data for house 364/900
# Scraped data for house 365/900
# Scraped data for house 366/900
# Scraped data for house 367/900
# Scraped data for house 368/900
# Scraped data for house 369/900
# Scraped data for house 370/900
# Scraped data for house 371/900
# Scraped data for house 372/900
# Scraped data for house 373/900
# Scraped data for house 374/900
# Scraped data for house 375/900
# Scraped data for house 376/900
# Scraped data for house 377/900
# Scraped data for house 378/900
# Scraped data for house 379/900
# Scraped data for house 380/900
# Scraped data for house 381/900
# Scraped data for house 382/900
# Scraped data for house 383/900
# Scraped data for house 384/900
# Scraped data for house 385/900
# Scraped data for house 386/900
# Scraped data for house 387/900
# Scraped data for house 388/900
# Scraped data for house 389/900
# Scraped data for house 390/900
# Scraped data for house 391/900
# Scraped data for house 392/900
# Scraped data for house 393/900
# Scraped data for house 394/900
# Scraped data for house 395/900
# Scraped data for house 396/900
# Scraped data for house 397/900
# Scraped data for house 398/900
# Scraped data for house 399/900
# Scraped data for house 400/900
# Scraped data for house 401/900
# Scraped data for house 402/900
# Scraped data for house 403/900
# Scraped data for house 404/900
# Scraped data for house 405/900
# Scraped data for house 406/900
# Scraped data for house 407/900
# Scraped data for house 408/900
# Scraped data for house 409/900
# Scraped data for house 410/900
# Scraped data for house 411/900
# Scraped data for house 412/900
# Scraped data for house 413/900
# Scraped data for house 414/900
# Scraped data for house 415/900
# Scraped data for house 416/900
# Scraped data for house 417/900
# Scraped data for house 418/900
# Scraped data for house 419/900
# Scraped data for house 420/900
# Scraped data for house 421/900
# Scraped data for house 422/900
# Scraped data for house 423/900
# Scraped data for house 424/900
# Scraped data for house 425/900
# Scraped data for house 426/900
# Scraped data for house 427/900
# Scraped data for house 428/900
# Scraped data for house 429/900
# Scraped data for house 430/900
# Scraped data for house 431/900
# Scraped data for house 432/900
# Scraped data for house 433/900

# %%
houses_df = pd.read_json(r"/content/Houses_data.json")
houses_df # convert to a dataset
# Out:
#                          name           price           property_type  \
# 0    Alamain (Latin District)   6,594,000 EGP  Residential, Apartment
# 1       Beachfront Tower - B1  66,104,000 EGP  Residential, Apartment
# 2                       PODIA  12,824,000 EGP      Commercial, Office
# 3          Mazarine Apartment  12,857,000 EGP  Residential, Apartment
# 4    Alamain (Latin District)   8,721,000 EGP  Residential, Apartment
# ..                        ...             ...                     ...
# 895                Latin City   7,967,000 EGP  Residential, Apartment
# 896  Alamain (Latin District)   7,063,000 EGP  Residential, Apartment
# 897                   Central  41,470,000 EGP      Commercial, Office
# 898                   Central  17,350,000 EGP      Commercial, Office
# 899     Beachfront Tower - B1  56,245,000 EGP  Residential, Apartment
#
#      bedrooms  bathrooms     sqm  year_built  \
# 0           1          0   92.86        2025
# 1           3          3  398.00        2025
# 2           0          0   93.00        2025
# 3           3          3  252.00        2025
# 4           3          0  209.42        2025
# ..        ...        ...     ...         ...
# 895         2          1  134.00        2025
# 896         4          0  229.35        2025
# 897         0          0  217.17        2025
# 898         0          0  176.52        2025
# 899         3          3  319.00        2025
#
#                                               features          city  \
# 0        [Other, Security Gate, Electricity Available]   North Coast
# 1                                              [Other]  Mersa Matruh
# 2    [Other, 24 Hour Security, Fire Alarm, Gate Com...         Cairo
# 3            [24 Hour Security, Electricity Available]  Mersa Matruh
# 4        [Other, Security Gate, Electricity Available]   North Coast
# ..                                                 ...           ...
# 895                          [24 Hour Security, Other]   North Coast
# 896      [Other, Security Gate, Electricity Available]   North Coast
# 897  [Elevator(s), Gate Community, Electricity Avai...     New Cairo
# 898  [Elevator(s), Gate Community, Electricity Avai...     New Cairo
# 899                                            [Other]  Mersa Matruh
#
#     governorate                                            address  \
# 0    Alexandria  Building F04 Floor 6 Unit Z02-CL05-F04-X7-06-1...
# 1       Matrouh  Building BTB1 Floor 9th floor Unit BTB1091 Bea...
# 2         Cairo  Floor 13th Unit MPO-1304-A Bin ZayedNorth PODI...
# 3       Matrouh  Building MZCS15 Floor 3rd floor Unit MZCS1531 ...
# 4    Alexandria  Building E01 Floor 1 Unit Z02-CL09-E01-X4-01-0...
# ..          ...                                                ...
# 895     Matrouh  Building Z3CL0401 Floor 5 Unit LC301508 Latin ...
# 896  Alexandria  Building A13 Floor 6 Unit Z05-CL11-A13-M7-06-0...
# 897       Cairo  Building O10 Floor 4 Unit O10-04-B Central New...
# 898       Cairo  Building O5 Floor 2 Unit O5-02-M Central New C...
# 899     Matrouh  Building BTB1 Floor 21th floor Unit BTB1218 Be...
#
#                                            description
# 0    Latini by Saudi Egyptian Developers (SED) – Ne...
# 1    Explore a lifestyle that allows you to have yo...
# 2    Launched by Menassat Developments in cooperati...
# 3    The name ‘Mazarine’ came to fruition based on ...
# 4    One of the main districts in this new city nei...
# ..                                                 ...
# 895  The Latin District is an expansion of the Alex...
# 896  Latini by Saudi Egyptian Developers (SED) – Ne...
# 897  True to its name, Central is situated at the c...
# 898  True to its name, Central is situated at the c...
# 899  Explore a lifestyle that allows you to have yo...
#
# [900 rows x 12 columns]

# %%
#Export it as a csv file
houses_df.to_csv("houses_data.csv", index=False)
