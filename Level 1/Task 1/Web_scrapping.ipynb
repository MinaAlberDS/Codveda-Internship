# %% [markdown]
# <a href="https://colab.research.google.com/github/MinaAlberDS/Codveda-Internship/blob/master/Level%201/Task%201/Web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scrapping, and collecting the data
#
# ### Collecting the Real Estates links

# %%
# Import the needed libraries
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
# Make the function which will get the real_estates links
def real_estates_links(pages:int,verbose:bool=True):
    """
    Scrapes real estate listing links from real estate ate.gov.eg.

    Args:
        pages: An integer representing the number of pages to scrape.
        verbose: A boolean indicating whether to print the progress of scraping each page.

    Returns:
        A list of strings, where each string is a URL to a real estate listing.
        :param pages: An integer representing the number of pages to scrape.
        :param verbose: A boolean indicating whether to print the progress of scraping each page.

    """
    base_url = r"https://realestate.gov.eg/ar/search/%D8%B4%D8%B1%D8%A7%D8%A1?page={}"
    links_list = [] # links list
    for page in range(1,pages+1): # This for loop to get the 9 real_estates links in each page
        start_time = time.perf_counter() # start a stop watch for each page
        page_url = base_url.format(page) # Set the page url from the baseline url using f-string or format
        response = requests.get(page_url) # Get the response of the page url
        if response.status_code == 200: # check if the page can be scrapped or not
          soap = BeautifulSoup(response.content, "html.parser") # set the soop variable to scrape the links from the page html
          real_estates = soap.find_all("div", class_="col-md-4")[3:] # get the real_estates links

          for real_estate in real_estates: # Add the real_estates links to the links list
              link = r"https://realestate.gov.eg" + real_estate.find("a")["href"] # Set the real_estate url
              links_list.append(link) # add it to the links list
          end_time = time.perf_counter() # stop the timer
          elapsed = end_time - start_time # count the elapsed time
          if verbose: # if the verbose is true, it will show some useful information about each page
              print(f"Page: {page} links have been appended in {elapsed:.4f}s")
        else: # if the page cannot be scraped
          print(f"failed to scrape this Page: {page} with code: {response.status_code}")
        time.sleep(0.5)
    return links_list # finally retrun the links list

# %%
links = real_estates_links(50, True) # running our function with 350 pages, and verbose = True
# Out:
# Page: 1 links have been appended in 2.2392s
# Page: 2 links have been appended in 2.1545s
# Page: 3 links have been appended in 2.1899s
# Page: 4 links have been appended in 2.1900s
# Page: 5 links have been appended in 2.1647s
# Page: 6 links have been appended in 2.2108s
# Page: 7 links have been appended in 2.3930s
# Page: 8 links have been appended in 2.1674s
# Page: 9 links have been appended in 2.2424s
# Page: 10 links have been appended in 2.4510s
# Page: 11 links have been appended in 2.8577s
# Page: 12 links have been appended in 2.3137s
# Page: 13 links have been appended in 2.2383s
# Page: 14 links have been appended in 2.1710s
# Page: 15 links have been appended in 2.1541s
# Page: 16 links have been appended in 2.1835s
# Page: 17 links have been appended in 2.1688s
# Page: 18 links have been appended in 2.2482s
# Page: 19 links have been appended in 2.3522s
# Page: 20 links have been appended in 2.2304s
# Page: 21 links have been appended in 2.1755s
# Page: 22 links have been appended in 2.1224s
# Page: 23 links have been appended in 2.2064s
# Page: 24 links have been appended in 2.1773s
# Page: 25 links have been appended in 2.1620s
# Page: 26 links have been appended in 2.2060s
# Page: 27 links have been appended in 2.2468s
# Page: 28 links have been appended in 3.2506s
# Page: 29 links have been appended in 2.2676s
# Page: 30 links have been appended in 2.2558s
# Page: 31 links have been appended in 2.2241s
# Page: 32 links have been appended in 2.1867s
# Page: 33 links have been appended in 2.4297s
# Page: 34 links have been appended in 2.1307s
# Page: 35 links have been appended in 2.1445s
# Page: 36 links have been appended in 2.1904s
# Page: 37 links have been appended in 2.2294s
# Page: 38 links have been appended in 2.3088s
# Page: 39 links have been appended in 2.2180s
# Page: 40 links have been appended in 2.1515s
# Page: 41 links have been appended in 2.7747s
# Page: 42 links have been appended in 2.1151s
# Page: 43 links have been appended in 2.1964s
# Page: 44 links have been appended in 2.2005s
# Page: 45 links have been appended in 2.1709s
# Page: 46 links have been appended in 2.2680s
# Page: 47 links have been appended in 2.4658s
# Page: 48 links have been appended in 2.2413s
# Page: 49 links have been appended in 2.1655s
# Page: 50 links have been appended in 2.1833s

# %%
len(links)
# Out:
# 450

# %% [markdown]
# |We have 504 real_estate to scrape

# %%
import json
# export the real_estates links to a json file
with open("Links.json", "w") as links_json:
    json.dump(links, links_json, indent =4)

# %%
# import the json file links to scrap them
with open("Links.json", "r") as links_json:
  links = json.load(links_json)
# show the results
links[:5]
# Out:
# ['https://realestate.gov.eg/ar/property-details/mamsha-avenue/new-administrative-capital/cairo/building-maa15b-floor-1-unit-maa15b14-mamsha-avenue-new-administrative-capital-cairo-cairo-egypt/E189166',
#  'https://realestate.gov.eg/ar/property-details/new-garden-city/new-administrative-capital/cairo/building-g883-floor-mezzanine-unit-g883mr10-new-garden-city-new-administrative-capital-cairo-cairo-egypt/E377964',
#  'https://realestate.gov.eg/ar/property-details/maspero-mall/cairo/cairo/building-mm-floor-ground-floor-unit-mmrtg24b-maspero-mall-cairo-cairo-cairo-egypt/E110528',
#  'https://realestate.gov.eg/ar/property-details/alamain-(latin-district)/north-coast/alexandria/building-a03-floor-3-unit-z05-cl08-a03-x4-03-05-alamain-(latin-district)-north-coast-alexandria-egypt/E375962',
#  'https://realestate.gov.eg/ar/property-details/zahya/mansoura/dakahlia/building-zh3m71-unit-zh3m71-zahya-mansoura-(m)-dakahlia-egypt/E110258']

# %% [markdown]
# ### Collect the real_estates data

# %%
import json

def collect_real_estate_data(real_estates_links:list, verbose:bool=True, except_2025:bool=False):
    """
    Scrapes real estate data from a list of real estate listing URLs.
    Args:
        real_estates_links: A list of strings, where each string is a URL to a real estate listing.
        verbose: A boolean indicating whether to print the progress of scraping each real estate listing.
        except_2025: A boolean indicating whether to exclude listings built in 2025.
    Returns:
        A dictionary containing lists of scraped data for each real estate listing.
    """
    # Initialize a dictionary to store data for all real_estates
    all_real_estates_data = {
        'name': [],
        'price': [],
        'property_type': [],
        'bedrooms': [],
        'bathrooms': [],
        'sqm': [],
        'year_built': [],
        'features': [],
        'city': [],
        'governorate': [],
        'address': [],
        'description': []
    }

    # Open the JSON file in append mode outside the loop
    with open("real_estates_data.json", "w") as real_estates_data:
        # Initialize the JSON file with an empty list
        json.dump([], real_estates_data)


    for i, real_estate_link in enumerate(real_estates_links): # get the data from each real_estate
        try:
            real_estate_response = requests.get(real_estate_link) # Get the request of the real_estate link
            real_estate_soop = BeautifulSoup(real_estate_response.content, "html.parser") # make the real_estate soop

            real_estate_div = real_estate_soop.find_all("div", class_= "propertySpecs_spec_box__xLU5D")
            if len(real_estate_div) > 0:
                year_built = real_estate_div[4].find_all("span")[1]

                if except_2025 and year_built and year_built.text.strip() not in ["2022","2023", "2024"]:
                    if verbose:
                        print(f"Skipping real_estate {i+1}/{len(real_estates_links)} built in 2025")
                    continue  # Skip this real_estate if it's built in 2025

                # Extract data, handling potential missing elements
                name = real_estate_soop.find("h6", class_= "propertyInfo_name__bs0i7")
                all_real_estates_data['name'].append(name.get_text(strip=True) if name else None)

                price = real_estate_soop.find("p", class_ = "propertyInfo_price__8ecPp")
                all_real_estates_data['price'].append(price.text.strip() if price else None)

                property_type = real_estate_div[0].find("span")
                all_real_estates_data['property_type'].append(property_type.text.strip() if property_type else None)

                # Extract bedroom, bathroom, sqm, and year built if available

                bedroom = real_estate_div[1].find_all("span")[1]
                all_real_estates_data['bedrooms'].append(bedroom.text.strip() if bedroom else None)
                bathroom = real_estate_div[2].find_all("span")[1]
                all_real_estates_data['bathrooms'].append(bathroom.text.strip() if bathroom else None)
                sqm = real_estate_div[3].find_all("span")[1]
                all_real_estates_data['sqm'].append(sqm.text.strip() if sqm else None)
                all_real_estates_data['year_built'].append(year_built.text.strip() if year_built else None)

            else:
                # Append None for property type and other specs if the main div is not found
                all_real_estates_data['property_type'].append(None)
                all_real_estates_data['bedrooms'].append(None)
                all_real_estates_data['bathrooms'].append(None)
                all_real_estates_data['sqm'].append(None)
                all_real_estates_data['year_built'].append(None)


            real_estate_features = []
            real_estate_features_dv = real_estate_soop.find_all("div", class_ = "col-md-6")
            for real_estate_feature in real_estate_features_dv:
                feature_text = real_estate_feature.find("h2")
                if feature_text:
                    real_estate_features.append(feature_text.get_text(strip=True))
            all_real_estates_data['features'].append(real_estate_features) # Append the list of features


            real_estate_city_div = real_estate_soop.find_all("div", class_= "propertyData_address_info_row__up8MX")
            if len(real_estate_city_div) > 2:
                city = real_estate_city_div[1].find_all("p")
                all_real_estates_data['city'].append(city[1].get_text(strip=True) if len(city) > 1 else None)

                governorate = real_estate_city_div[2].find_all("p")
                all_real_estates_data['governorate'].append(governorate[1].get_text(strip=True) if len(governorate) > 1 else None)
            else:
                # Append None if city and governorate details are not found
                all_real_estates_data['city'].append(None)
                all_real_estates_data['governorate'].append(None)


            address_div = real_estate_soop.find("div", class_="propertyData_address_info_row__up8MX propertyData_address_row__vZiYP")
            if address_div:
                address = address_div.find_all("p")
                all_real_estates_data['address'].append(address[1].get_text(strip=True) if len(address) > 1 else None)
            else:
                # Append None if address is not found
                all_real_estates_data['address'].append(None)

            description_div = real_estate_soop.find("div", class_= "propertyData_property_long_description__mAJPf")
            if description_div:
                 # Extract text from each paragraph tag and join them
                 paragraph_texts = [p.get_text(strip=True) for p in description_div.find_all("p")]
                 full_description = "".join(paragraph_texts)
                 all_real_estates_data['description'].append(full_description)
            else:
                # Append None if description is not found
                all_real_estates_data['description'].append(None)


            # Append the data of the current real_estate to the JSON file
            with open("real_estates_data.json", "r+") as real_estates_data:
                data = json.load(real_estates_data)
                data.append({key: all_real_estates_data[key][-1] for key in all_real_estates_data})  # Append the last added data
                real_estates_data.seek(0) # the begining of the file
                json.dump(data, real_estates_data, indent=4) # Add the real_estate data
                real_estates_data.truncate() # The beining of the file

            if verbose:
                print(f"Scraped data for real_estate {i+1}/{len(real_estates_links)}")

        except Exception as e:
            print(f"Error scraping {real_estate_link}: {e}")
            # Append None for all fields if an error occurs during scraping
            for key in all_real_estates_data:
                all_real_estates_data[key].append(None)

        time.sleep(0.5)
    return all_real_estates_data

# %%
real_estates_data = collect_real_estate_data(links, except_2025=True)
real_estates_data
# Out:
# Skipping real_estate 1/450 built in 2025
# Skipping real_estate 2/450 built in 2025
# Scraped data for real_estate 3/450
# Skipping real_estate 4/450 built in 2025
# Scraped data for real_estate 5/450
# Skipping real_estate 6/450 built in 2025
# Skipping real_estate 7/450 built in 2025
# Skipping real_estate 8/450 built in 2025
# Skipping real_estate 9/450 built in 2025
# Skipping real_estate 10/450 built in 2025
# Scraped data for real_estate 11/450
# Scraped data for real_estate 12/450
# Scraped data for real_estate 13/450
# Skipping real_estate 14/450 built in 2025
# Skipping real_estate 15/450 built in 2025
# Skipping real_estate 16/450 built in 2025
# Skipping real_estate 17/450 built in 2025
# Skipping real_estate 18/450 built in 2025
# Skipping real_estate 19/450 built in 2025
# Skipping real_estate 20/450 built in 2025
# Skipping real_estate 21/450 built in 2025
# Skipping real_estate 22/450 built in 2025
# Skipping real_estate 23/450 built in 2025
# Skipping real_estate 24/450 built in 2025
# Scraped data for real_estate 25/450
# Skipping real_estate 26/450 built in 2025
# Skipping real_estate 27/450 built in 2025
# Skipping real_estate 28/450 built in 2025
# Skipping real_estate 29/450 built in 2025
# Skipping real_estate 30/450 built in 2025
# Skipping real_estate 31/450 built in 2025
# Scraped data for real_estate 32/450
# Skipping real_estate 33/450 built in 2025
# Skipping real_estate 34/450 built in 2025
# Scraped data for real_estate 35/450
# Skipping real_estate 36/450 built in 2025
# Skipping real_estate 37/450 built in 2025
# Skipping real_estate 38/450 built in 2025
# Skipping real_estate 39/450 built in 2025
# Skipping real_estate 40/450 built in 2025
# Skipping real_estate 41/450 built in 2025
# Skipping real_estate 42/450 built in 2025
# Skipping real_estate 43/450 built in 2025
# Skipping real_estate 44/450 built in 2025
# Skipping real_estate 45/450 built in 2025
# Skipping real_estate 46/450 built in 2025
# Skipping real_estate 47/450 built in 2025
# Skipping real_estate 48/450 built in 2025
# Skipping real_estate 49/450 built in 2025
# Skipping real_estate 50/450 built in 2025
# Scraped data for real_estate 51/450
# Skipping real_estate 52/450 built in 2025
# Skipping real_estate 53/450 built in 2025
# Skipping real_estate 54/450 built in 2025
# Skipping real_estate 55/450 built in 2025
# Skipping real_estate 56/450 built in 2025
# Skipping real_estate 57/450 built in 2025
# Skipping real_estate 58/450 built in 2025
# Skipping real_estate 59/450 built in 2025
# Skipping real_estate 60/450 built in 2025
# Skipping real_estate 61/450 built in 2025
# Skipping real_estate 62/450 built in 2025
# Scraped data for real_estate 63/450
# Scraped data for real_estate 64/450
# Skipping real_estate 65/450 built in 2025
# Skipping real_estate 66/450 built in 2025
# Skipping real_estate 67/450 built in 2025
# Skipping real_estate 68/450 built in 2025
# Skipping real_estate 69/450 built in 2025
# Skipping real_estate 70/450 built in 2025
# Skipping real_estate 71/450 built in 2025
# Skipping real_estate 72/450 built in 2025
# Skipping real_estate 73/450 built in 2025
# Skipping real_estate 74/450 built in 2025
# Skipping real_estate 75/450 built in 2025
# Scraped data for real_estate 76/450
# Skipping real_estate 77/450 built in 2025
# Scraped data for real_estate 78/450
# Skipping real_estate 79/450 built in 2025
# Skipping real_estate 80/450 built in 2025
# Scraped data for real_estate 81/450
# Skipping real_estate 82/450 built in 2025
# Skipping real_estate 83/450 built in 2025
# Skipping real_estate 84/450 built in 2025
# Skipping real_estate 85/450 built in 2025
# Skipping real_estate 86/450 built in 2025
# Scraped data for real_estate 87/450
# Skipping real_estate 88/450 built in 2025
# Skipping real_estate 89/450 built in 2025
# Skipping real_estate 90/450 built in 2025
# Skipping real_estate 91/450 built in 2025
# Skipping real_estate 92/450 built in 2025
# Skipping real_estate 93/450 built in 2025
# Scraped data for real_estate 94/450
# Skipping real_estate 95/450 built in 2025
# Skipping real_estate 96/450 built in 2025
# Skipping real_estate 97/450 built in 2025
# Skipping real_estate 98/450 built in 2025
# Skipping real_estate 99/450 built in 2025
# Skipping real_estate 100/450 built in 2025
# Skipping real_estate 101/450 built in 2025
# Skipping real_estate 102/450 built in 2025
# Scraped data for real_estate 103/450
# Skipping real_estate 104/450 built in 2025
# Skipping real_estate 105/450 built in 2025
# Skipping real_estate 106/450 built in 2025
# Skipping real_estate 107/450 built in 2025
# Skipping real_estate 108/450 built in 2025
# Scraped data for real_estate 109/450
# Skipping real_estate 110/450 built in 2025
# Skipping real_estate 111/450 built in 2025
# Skipping real_estate 112/450 built in 2025
# Skipping real_estate 113/450 built in 2025
# Skipping real_estate 114/450 built in 2025
# Scraped data for real_estate 115/450
# Skipping real_estate 116/450 built in 2025
# Skipping real_estate 117/450 built in 2025
# Skipping real_estate 118/450 built in 2025
# Skipping real_estate 119/450 built in 2025
# Skipping real_estate 120/450 built in 2025
# Skipping real_estate 121/450 built in 2025
# Skipping real_estate 122/450 built in 2025
# Skipping real_estate 123/450 built in 2025
# Scraped data for real_estate 124/450
# Skipping real_estate 125/450 built in 2025
# Scraped data for real_estate 126/450
# Skipping real_estate 127/450 built in 2025
# Skipping real_estate 128/450 built in 2025
# Skipping real_estate 129/450 built in 2025
# Skipping real_estate 130/450 built in 2025
# Scraped data for real_estate 131/450
# Scraped data for real_estate 132/450
# Skipping real_estate 133/450 built in 2025
# Scraped data for real_estate 134/450
# Scraped data for real_estate 135/450
# Scraped data for real_estate 136/450
# Skipping real_estate 137/450 built in 2025
# Skipping real_estate 138/450 built in 2025
# Skipping real_estate 139/450 built in 2025
# Skipping real_estate 140/450 built in 2025
# Skipping real_estate 141/450 built in 2025
# Skipping real_estate 142/450 built in 2025
# Skipping real_estate 143/450 built in 2025
# Skipping real_estate 144/450 built in 2025
# Scraped data for real_estate 145/450
# Skipping real_estate 146/450 built in 2025
# Skipping real_estate 147/450 built in 2025
# Skipping real_estate 148/450 built in 2025
# Skipping real_estate 149/450 built in 2025
# Skipping real_estate 150/450 built in 2025
# Skipping real_estate 151/450 built in 2025
# Skipping real_estate 152/450 built in 2025
# Skipping real_estate 153/450 built in 2025
# Skipping real_estate 154/450 built in 2025
# Skipping real_estate 155/450 built in 2025
# Skipping real_estate 156/450 built in 2025
# Skipping real_estate 157/450 built in 2025
# Skipping real_estate 158/450 built in 2025
# Skipping real_estate 159/450 built in 2025
# Skipping real_estate 160/450 built in 2025
# Skipping real_estate 161/450 built in 2025
# Skipping real_estate 162/450 built in 2025
# Skipping real_estate 163/450 built in 2025
# Skipping real_estate 164/450 built in 2025
# Skipping real_estate 165/450 built in 2025
# Skipping real_estate 166/450 built in 2025
# Skipping real_estate 167/450 built in 2025
# Skipping real_estate 168/450 built in 2025
# Skipping real_estate 169/450 built in 2025
# Skipping real_estate 170/450 built in 2025
# Skipping real_estate 171/450 built in 2025
# Skipping real_estate 172/450 built in 2025
# Skipping real_estate 173/450 built in 2025
# Skipping real_estate 174/450 built in 2025
# Skipping real_estate 175/450 built in 2025
# Skipping real_estate 176/450 built in 2025
# Skipping real_estate 177/450 built in 2025
# Skipping real_estate 178/450 built in 2025
# Skipping real_estate 179/450 built in 2025
# Skipping real_estate 180/450 built in 2025
# Skipping real_estate 181/450 built in 2025
# Skipping real_estate 182/450 built in 2025
# Skipping real_estate 183/450 built in 2025
# Skipping real_estate 184/450 built in 2025
# Skipping real_estate 185/450 built in 2025
# Scraped data for real_estate 186/450
# Skipping real_estate 187/450 built in 2025
# Skipping real_estate 188/450 built in 2025
# Skipping real_estate 189/450 built in 2025
# Skipping real_estate 190/450 built in 2025
# Skipping real_estate 191/450 built in 2025
# Scraped data for real_estate 192/450
# Skipping real_estate 193/450 built in 2025
# Skipping real_estate 194/450 built in 2025
# Skipping real_estate 195/450 built in 2025
# Skipping real_estate 196/450 built in 2025
# Skipping real_estate 197/450 built in 2025
# Skipping real_estate 198/450 built in 2025
# Skipping real_estate 199/450 built in 2025
# Skipping real_estate 200/450 built in 2025
# Skipping real_estate 201/450 built in 2025
# Skipping real_estate 202/450 built in 2025
# Skipping real_estate 203/450 built in 2025
# Scraped data for real_estate 204/450
# Skipping real_estate 205/450 built in 2025
# Skipping real_estate 206/450 built in 2025
# Skipping real_estate 207/450 built in 2025
# Skipping real_estate 208/450 built in 2025
# Skipping real_estate 209/450 built in 2025
# Scraped data for real_estate 210/450
# Skipping real_estate 211/450 built in 2025
# Skipping real_estate 212/450 built in 2025
# Skipping real_estate 213/450 built in 2025
# Skipping real_estate 214/450 built in 2025
# Error scraping https://realestate.gov.eg/ar/property-details/zahya/mansoura/dakahlia/building-zh1c317b-floor-ground-floor-unit-zh1c317b-zahya-mansoura-(m)-dakahlia-egypt/E110509: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error scraping https://realestate.gov.eg/ar/property-details/alamain-(latin-district)/north-coast/alexandria/building-a02-floor-4-unit-z02-cl03-a02-m7-04-01-alamain-(latin-district)-north-coast-alexandria-egypt/E358552: HTTPSConnectionPool(host='realestate.gov.eg', port=443): Max retries exceeded with url: /ar/property-details/alamain-(latin-district)/north-coast/alexandria/building-a02-floor-4-unit-z02-cl03-a02-m7-04-01-alamain-(latin-district)-north-coast-alexandria-egypt/E358552 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000019519642AD0>: Failed to resolve 'realestate.gov.eg' ([Errno 11001] getaddrinfo failed)"))
# Error scraping https://realestate.gov.eg/ar/property-details/zahya/mansoura/dakahlia/building-zh3m232-unit-zh3m232b-zahya-mansoura-(m)-dakahlia-egypt/E110649: HTTPSConnectionPool(host='realestate.gov.eg', port=443): Max retries exceeded with url: /ar/property-details/zahya/mansoura/dakahlia/building-zh3m232-unit-zh3m232b-zahya-mansoura-(m)-dakahlia-egypt/E110649 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000019516FD2FD0>: Failed to resolve 'realestate.gov.eg' ([Errno 11001] getaddrinfo failed)"))
# Skipping real_estate 218/450 built in 2025
# Skipping real_estate 219/450 built in 2025
# Scraped data for real_estate 220/450
# Skipping real_estate 221/450 built in 2025
# Skipping real_estate 222/450 built in 2025
# Skipping real_estate 223/450 built in 2025
# Skipping real_estate 224/450 built in 2025
# Skipping real_estate 225/450 built in 2025
# Skipping real_estate 226/450 built in 2025
# Skipping real_estate 227/450 built in 2025
# Scraped data for real_estate 228/450
# Skipping real_estate 229/450 built in 2025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 real_estates_data = collect_real_estate_data(links, except_2025=True)
#       2 real_estates_data
#
# Cell In[35], line 37, in collect_real_estate_data(real_estates_links, verbose, except_2025)
#      35 for i, real_estate_link in enumerate(real_estates_links): # get the data from each real_estate
#      36     try:
# ---> 37         real_estate_response = requests.get(real_estate_link) # Get the request of the real_estate link
#      38         real_estate_soop = BeautifulSoup(real_estate_response.content, "html.parser") # make the real_estate soop
#      40         real_estate_div = real_estate_soop.find_all("div", class_= "propertySpecs_spec_box__xLU5D")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Exporting the data

# %%
real_estates_df = pd.read_json(r"real_estates_data.json")
real_estates_df # convert to a dataset
# Out:
#                                    name           price  \
# 0                          Maspero mall  17,886,000 ج م
# 1                                 Zahya  17,536,000 ج م
# 2                                 Zahya  22,024,000 ج م
# 3                                 Zahya  10,249,000 ج م
# 4                                 Zahya  17,478,000 ج م
# 5                                 Zahya   9,850,000 ج م
# 6                                 Zahya  18,389,000 ج م
# 7                                 Zahya  10,197,000 ج م
# 8                                 Zahya   9,962,000 ج م
# 9                                 Zahya  10,612,000 ج م
# 10  Maspero Business Tower Nile Heights   6,846,000 ج م
# 11                                Zahya  21,758,000 ج م
# 12                                Zahya  10,649,000 ج م
# 13                                Zahya  10,226,000 ج م
# 14                                Zahya  11,114,000 ج م
# 15                                Zahya  10,495,000 ج م
# 16                                Zahya  10,511,000 ج م
# 17                                Zahya   9,857,000 ج م
# 18                                Zahya  24,478,000 ج م
# 19  Maspero Business Tower Nile Heights  11,856,000 ج م
# 20                                Zahya  11,266,000 ج م
# 21                                Zahya  22,024,000 ج م
# 22                                Zahya  10,557,000 ج م
# 23                                Zahya  10,578,000 ج م
# 24                                Zahya  11,502,000 ج م
# 25                                Zahya   9,787,000 ج م
# 26                                Zahya  11,400,000 ج م
# 27                                Zahya  10,557,000 ج م
# 28                                Zahya  10,898,000 ج م
# 29  Maspero Business Tower Nile Heights  11,506,000 ج م
# 30  Maspero Business Tower Nile Heights  11,856,000 ج م
# 31                                Zahya  10,154,000 ج م
# 32                                Zahya  11,690,000 ج م
#
#                        property_type  bedrooms  bathrooms    sqm  year_built  \
# 0   تجاري, مبنى البيع بالتجزئة / مول         0          0  117.0        2023
# 1                         سكني, فيلا         3          2  600.2        2024
# 2                         سكني, فيلا         3          0  891.0        2024
# 3                    سكني, توين هاوس         3          0  350.5        2024
# 4                         سكني, فيلا         3          2  600.2        2024
# 5                    سكني, توين هاوس         3          0  308.0        2024
# 6                         سكني, فيلا         3          2  746.5        2024
# 7                    سكني, توين هاوس         3          0  410.0        2024
# 8                    سكني, تاون هاوس         3          0  392.0        2024
# 9                    سكني, توين هاوس         3          0  410.0        2024
# 10                       تجاري, مكتب         0          0  105.0        2023
# 11                        سكني, فيلا         3          0  860.0        2024
# 12                   سكني, تاون هاوس         3          0  377.3        2024
# 13                   سكني, تاون هاوس         3          0  392.0        2024
# 14                   سكني, توين هاوس         3          0  400.5        2024
# 15                   سكني, توين هاوس         3          0  410.0        2024
# 16                   سكني, توين هاوس         3          0  410.0        2024
# 17                   سكني, توين هاوس         3          0  309.0        2024
# 18                        سكني, فيلا         3          0  780.0        2024
# 19                       تجاري, مكتب         0          0  168.0        2023
# 20                   سكني, توين هاوس         3          0  410.0        2024
# 21                        سكني, فيلا         3          0  891.0        2024
# 22                   سكني, توين هاوس         3          0  410.0        2024
# 23                   سكني, توين هاوس         3          0  410.0        2024
# 24                   سكني, توين هاوس         3          0  498.0        2024
# 25                   سكني, توين هاوس         3          0  300.0        2024
# 26                   سكني, توين هاوس         3          0  328.0        2024
# 27                   سكني, توين هاوس         3          0  410.0        2024
# 28                   سكني, تاون هاوس         3          0  504.0        2024
# 29                       تجاري, مكتب         0          0  176.0        2023
# 30                       تجاري, مكتب         0          0  168.0        2023
# 31                   سكني, توين هاوس         3          0  410.0        2024
# 32                   سكني, توين هاوس         3          0  498.0        2024
#
#                                            features      city governorate  \
# 0               [أخرى, أمن 24 ساعة, الكهرباء متاحة]     Cairo       Cairo
# 1             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 2             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 3             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 4             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 5             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 6             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 7             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 8             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 9             [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 10  [أخرى, أمن 24 ساعة, مجتمع مسور, الكهرباء متاحة]     Cairo       Cairo
# 11            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 12            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 13            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 14            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 15            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 16            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 17            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 18            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 19  [أخرى, أمن 24 ساعة, مجتمع مسور, الكهرباء متاحة]     Cairo       Cairo
# 20            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 21            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 22            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 23            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 24            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 25            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 26            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 27            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 28            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 29  [أخرى, أمن 24 ساعة, مجتمع مسور, الكهرباء متاحة]     Cairo       Cairo
# 30  [أخرى, أمن 24 ساعة, مجتمع مسور, الكهرباء متاحة]     Cairo       Cairo
# 31            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
# 32            [اللوبي, أمن 24 ساعة, الكهرباء متاحة]  Mansoura    Dakahlia
#
#                                               address  \
# 0   Building MM Floor Ground floor Unit MMRTG24B M...
# 1   Building ZH3M71 Unit ZH3M71 Zahya Mansoura (m)...
# 2   Building ZH1C69 Floor Ground floor Unit ZH1C69...
# 3   Building ZHM219 Floor Ground floor Unit ZHM219...
# 4   Building ZH3M72 Unit ZH3M72 Zahya Mansoura (m)...
# 5   Building ZHC226 Floor Ground floor Unit ZHC226...
# 6   Building ZH3M106 Unit ZH3M106 Zahya Mansoura (...
# 7   Building ZH3M211 Unit ZH3M211A Zahya Mansoura ...
# 8   Building ZH3M239 Unit ZH3M239A Zahya Mansoura ...
# 9   Building ZH3M217 Unit ZH3M217B Zahya Mansoura ...
# 10  Building MBT Floor 10th floor Unit MBTAD103 Ma...
# 11  Building ZH1C70 Floor Ground floor Unit ZH1C70...
# 12  Building ZHM253 Floor Ground floor Unit ZHM253...
# 13  Building ZHM254 Floor Ground Unit ZHM254D Zahy...
# 14  Building ZHM223 Floor Ground floor Unit ZHM223...
# 15  Building ZH3M221 Unit ZH3M221B Zahya Mansoura ...
# 16  Building ZH3M216 Unit ZH3M216B Zahya Mansoura ...
# 17  Building ZHC225 Floor Ground floor Unit ZHC225...
# 18  Building ZH1C156 Floor Ground floor Unit ZH1C1...
# 19  Building NH Floor 2nd floor Unit NHAD0205 Masp...
# 20  Building ZH3M205 Unit ZH3M205B Zahya Mansoura ...
# 21  Building ZH1C69 Floor Ground floor Unit ZH1C69...
# 22  Building ZH3M209 Unit ZH3M209B Zahya Mansoura ...
# 23  Building ZH3M222 Unit ZH3M222B Zahya Mansoura ...
# 24  Building ZH3M233 Unit ZH3M233B Zahya Mansoura ...
# 25  Building ZHC224 Floor Ground floor Unit ZHC224...
# 26  Building ZH1C325B Floor Ground floor Unit ZH1C...
# 27  Building ZH3M209 Unit ZH3M209B Zahya Mansoura ...
# 28  Building ZH3M244 Unit ZH3M244C Zahya Mansoura ...
# 29  Building NH Floor 3rd floor Unit NHAD0306 Masp...
# 30  Building NH Floor 2nd floor Unit NHAD0205 Masp...
# 31  Building ZH3M212 Unit ZH3M212A Zahya Mansoura ...
# 32  Building ZH3M235 Unit ZH3M235A Zahya Mansoura ...
#
#                                           description
# 0   يُعد ماسبيرو مول وجهة فريدة لتجارب التسوق ونمط...
# 1   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 2   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 3   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 4   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 5   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 6   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 7   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 8   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 9   بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 10  من الإطلالات الخلابة على أفق القاهرة المتألّق ...
# 11  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 12  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 13  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 14  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 15  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 16  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 17  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 18  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 19  من الإطلالات الخلابة على أفق القاهرة المتألّق ...
# 20  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 21  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 22  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 23  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 24  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 25  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 26  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 27  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 28  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 29  من الإطلالات الخلابة على أفق القاهرة المتألّق ...
# 30  من الإطلالات الخلابة على أفق القاهرة المتألّق ...
# 31  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...
# 32  بصفتنا شركة عقارية رائدة تُعنى ببناء مشروع سكن...

# %%
#Export it as a csv file
real_estates_df.to_csv("real_estates_data.csv", index=False)

# %% [markdown]
# I scrapped more 283 rows, so the final output is 1183 rows

# %%
re_df = pd.read_csv(r"real_estates_data.csv")
re_df_77 = pd.read_csv(r"real_estates_data(1).csv")
re_df_206 = pd.read_csv(r"real_estates_data(2).csv")

# Concatenate all dataframes vertically (row-wise)
re_df = pd.concat([re_df, re_df_77, re_df_206], ignore_index=True)

re_df
# Out:
#                           name           price           property_type  \
# 0     Alamain (Latin District)   6,594,000 EGP  Residential, Apartment
# 1        Beachfront Tower - B1  66,104,000 EGP  Residential, Apartment
# 2                        PODIA  12,824,000 EGP      Commercial, Office
# 3           Mazarine Apartment  12,857,000 EGP  Residential, Apartment
# 4     Alamain (Latin District)   8,721,000 EGP  Residential, Apartment
# ...                        ...             ...                     ...
# 1178             T- Residences   2,668,259 EGP  Residential, Apartment
# 1179  Alamain (Latin District)   3,226,000 EGP  Residential, Apartment
# 1180       Downtown commercial  20,540,000 EGP      Commercial, Retail
# 1181  Alamain (Latin District)   6,512,000 EGP  Residential, Apartment
# 1182           New Garden City   6,956,000 EGP  Residential, Apartment
#
#       bedrooms  bathrooms     sqm  year_built  \
# 0            1          0   92.86        2025
# 1            3          3  398.00        2025
# 2            0          0   93.00        2025
# 3            3          3  252.00        2025
# 4            3          0  209.42        2025
# ...        ...        ...     ...         ...
# 1178         3          1  120.00        2024
# 1179         1          0   94.61        2025
# 1180         0          0  200.00        2025
# 1181         4          0  213.53        2025
# 1182         2          0  166.00        2025
#
#                                                features  \
# 0     ['Other', 'Security Gate', 'Electricity Availa...
# 1                                             ['Other']
# 2     ['Other', '24 Hour Security', 'Fire Alarm', 'G...
# 3         ['24 Hour Security', 'Electricity Available']
# 4     ['Other', 'Security Gate', 'Electricity Availa...
# ...                                                 ...
# 1178  ['24 Hour Security', 'Electricity Available', ...
# 1179  ['Other', 'Security Gate', 'Electricity Availa...
# 1180  ['Other', '24 Hour Security', 'Electricity Ava...
# 1181  ['Other', 'Security Gate', 'Electricity Availa...
# 1182        ['Gate Community', 'Natural Gas Available']
#
#                             city governorate  \
# 0                    North Coast  Alexandria
# 1                   Mersa Matruh     Matrouh
# 2                          Cairo       Cairo
# 3                   Mersa Matruh     Matrouh
# 4                    North Coast  Alexandria
# ...                          ...         ...
# 1178                 North Coast     Matrouh
# 1179                 North Coast  Alexandria
# 1180                Mersa Matruh     Matrouh
# 1181                 North Coast  Alexandria
# 1182  New Administrative Capital       Cairo
#
#                                                 address  \
# 0     Building F04 Floor 6 Unit Z02-CL05-F04-X7-06-1...
# 1     Building BTB1 Floor 9th floor Unit BTB1091 Bea...
# 2     Floor 13th Unit MPO-1304-A Bin ZayedNorth PODI...
# 3     Building MZCS15 Floor 3rd floor Unit MZCS1531 ...
# 4     Building E01 Floor 1 Unit Z02-CL09-E01-X4-01-0...
# ...                                                 ...
# 1178  Building C-12 Floor 6 Unit 62 T- Residences No...
# 1179  Building D15 Floor 7 Unit Z02-CL07-D15-X7-07-0...
# 1180  Building DT01 Floor Ground floor Unit DTRG0130...
# 1181  Building C06 Floor 1 Unit Z05-CL11-C06-M7-01-0...
# 1182  Building G645 Floor 7th floor Unit G64576 New ...
#
#                                             description
# 0     Latini by Saudi Egyptian Developers (SED) – Ne...
# 1     Explore a lifestyle that allows you to have yo...
# 2     Launched by Menassat Developments in cooperati...
# 3     The name ‘Mazarine’ came to fruition based on ...
# 4     One of the main districts in this new city nei...
# ...                                                 ...
# 1178  "Torec Developments is a subsidiary of the New...
# 1179  Latini by Saudi Egyptian Developers (SED) – Ne...
# 1180  Designed to be an integrated residential and c...
# 1181  Latini by Saudi Egyptian Developers (SED) – Ne...
# 1182  To live in a world, where you can see and sens...
#
# [1183 rows x 12 columns]

# %%
re_df.to_csv("real_estates_data(new).csv", index=False)
